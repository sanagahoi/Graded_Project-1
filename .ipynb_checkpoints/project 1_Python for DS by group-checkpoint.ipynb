# %% [markdown]
# ● <strong>Load and explore data
# 1. Import the required libraries and read the dataset.
# 2. Check the first few samples, shape, info of the data and try to familiarize
# yourself with different features.
# 3. Drop the columns which you think redundant for the analysis.
#
# [Hint: columns like 'Photo','Flag','Club Logo']</strong>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style ="ticks")
import warnings
warnings.filterwarnings('ignore')

# %%
fifa_Var_Info=pd.read_csv('fifa_ variable_information.csv')
Fifa_Df = pd.read_csv('fifa.csv')
Fifa_Df.describe().head(5)
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
#
#            Crossing     Finishing  HeadingAccuracy  ShortPassing  \
# count  18159.000000  18159.000000     18159.000000  18159.000000
# ...

# %%
#fifa_ variable_information discription
fifa_Var_Info.describe().T
# Out:
#                            count unique                     top freq
# ID                            59     59                    Name    1
# unique id for every player    59     25  rating on scale of 100   33

# %%
#Get statistical summary
Fifa_Df.describe().T
#check if the columns are having null value or not
Fifa_Df.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# ...

# %%
#Data information on fifa table
Fifa_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 60 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Photo                     18207 non-null  object
#  4   Nationality               18207 non-null  object
#  5   Flag                      18207 non-null  object
#  6   Overall                   18207 non-null  int64
#  7   Potential                 18207 non-null  int64
#  8   Club                      17966 non-null  object
#  9   Club Logo                 18207 non-null  object
#  10  Value                     18207 non-null  object
#  11  Wage                      18207 non-null  object
#  12  Preferred Foot            18159 non-null  object
# ...

# %%
#Shape of the data
Fifa_Df.shape
## indicates 60 columns and 18207 rows
# Out:
# (18207, 60)

# %% [markdown]
# <strong>● Data Cleaning and Preprocessing
#
# 4. Convert the columns "Value", "Wage", "Release Clause" to float datatype
# after getting rid of currency symbol and suffix.
# - Note: When the record/entry has "M"(indicates millions) as suffix you
# need to multiply that value with 1000000
# - When the record/entry has "K"(indicates thousands) as suffix you
# need to multiply that value with 1000</strong>

# %%
## Unique values and field to be dropped

print("Unique vaules in club logo,flag and Photo")
print(Fifa_Df['Club Logo'].nunique(),Fifa_Df['Flag'].nunique(),Fifa_Df['Photo'].nunique())
# Out:
# Unique vaules in club logo,flag and Photo
# 679 164 18207

# %%
## Drop redundant columns
# Fifa_Df.drop('Club Logo',axis=1,inplace=True)
# Fifa_Df.drop('Photo',axis=1,inplace=True)
# Fifa_Df.drop('Flag',axis=1,inplace=True)
# Fifa_Df.drop('Loaned From',axis=1,inplace=True)
Fifa_Clean=Fifa_Df.drop(columns=['Club Logo','Photo','Flag','Loaned From'],axis=1,inplace=True)

# %%
Fifa_Df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club    Value   Wage Preferred Foot  \
# 0         FC Barcelona  €110.5M  €565K           Left
# 1             Juventus     €77M  €405K          Right
# 2  Paris Saint-Germain  €118.5M  €290K          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# 1                       5.0        4.0          5.0       High/ Low
# 2                       5.0        5.0          5.0    High/ Medium
#
#     Body Type Position  Jersey Number        Joined Contract Valid Until  \
# 0       Messi       RF           10.0   Jul 1, 2004                 2021
# ...

# %%
# Getting rid of currency symbol and suffix.
Fifa_Df['Value']=Fifa_Df['Value'].str.replace("€","")
Fifa_Df['Wage']=Fifa_Df['Wage'].str.replace("€","")
Fifa_Df['Release Clause']=Fifa_Df['Release Clause'].str.replace("€","")

# %%
Fifa_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     18207 non-null  object
#  8   Wage                      18207 non-null  object
#  9   Preferred Foot            18159 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Weak Foot                 18159 non-null  float64
#  12  Skill Moves               18159 non-null  float64
# ...

# %%
#Function to replace "M" to 1000000 , "K" to 1000 and replace empty values to 0
def varb_clear(arg):
    a=1
    if pd.isnull(arg) == True:
        arg = 0
        a = 0
    else:
        if 'M' in arg:
            a = 1000000
        elif 'K' in arg:
            a = 1000
        else:
            a = 1
        arg = arg.replace('M','').replace('K','')

    return(float(arg) * a)

# %%
#Remove NaN values in columns such as 'Value' 'Wage' 'Release Clause'
Fifa_Df.fillna({'Value':0},inplace=True)
Fifa_Df.fillna({'Wage':0},inplace=True)
Fifa_Df.fillna({'Release Clause':0},inplace=True)

# %%
Fifa_Df['Release Clause'].dtype
# Out:
# dtype('O')

# %%
#Calling function varb_clear() to remove 'M' ,'K' in replace digits
Fifa_Df['Value']=Fifa_Df.apply(lambda l:varb_clear(l['Value']),axis=1)
Fifa_Df['Wage']=Fifa_Df.apply(lambda a:varb_clear(a['Wage']),axis=1)
Fifa_Df['Release Clause']=Fifa_Df.apply(lambda m:varb_clear(m['Release Clause']), axis=1)

# %%
Fifa_Df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club        Value      Wage Preferred Foot  \
# 0         FC Barcelona  110500000.0  565000.0           Left
# 1             Juventus   77000000.0  405000.0          Right
# 2  Paris Saint-Germain  118500000.0  290000.0          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# 1                       5.0        4.0          5.0       High/ Low
# 2                       5.0        5.0          5.0    High/ Medium
#
#     Body Type Position  Jersey Number        Joined Contract Valid Until  \
# 0       Messi       RF           10.0   Jul 1, 2004                 2021
# ...

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# <strong>5. Convert the column "Joined" into integer data type with keeping only the
# year.</strong>

# %%
#Convert the column "Joined" into integer data type with keeping only the year
Fifa_Df.fillna({'Joined':'0000'}, inplace=True)
Fifa_Df['Joined'] = Fifa_Df['Joined'].str[-4:].astype(int)
Fifa_Df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club        Value      Wage Preferred Foot  \
# 0         FC Barcelona  110500000.0  565000.0           Left
# 1             Juventus   77000000.0  405000.0          Right
# 2  Paris Saint-Germain  118500000.0  290000.0          Right
# 3    Manchester United   72000000.0  260000.0          Right
# 4      Manchester City  102000000.0  355000.0          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# ...

# %% [markdown]
# <strong>6. Convert the column "Contract Valid Until" to pandas datetime type.</strong>

# %%
# Convert the column "Contract Valid Until" to pandas datetime type
contract=Fifa_Df['Contract Valid Until']
contract=np.where(contract.isnull(),np.nan, ('12/31/' + contract))
Fifa_Df['Contract Valid Until']=pd.to_datetime(contract,errors='coerce')
Fifa_Df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club        Value      Wage Preferred Foot  \
# 0         FC Barcelona  110500000.0  565000.0           Left
# 1             Juventus   77000000.0  405000.0          Right
# 2  Paris Saint-Germain  118500000.0  290000.0          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# 1                       5.0        4.0          5.0       High/ Low
# 2                       5.0        5.0          5.0    High/ Medium
#
#     Body Type Position  Jersey Number  Joined Contract Valid Until Height  \
# 0       Messi       RF           10.0    2004           2021-12-31    5'7
# ...

# %%
Fifa_Df.dtypes
# Out:
# ID                                   int64
# Name                                object
# Age                                  int64
# Nationality                         object
# Overall                              int64
# Potential                            int64
# Club                                object
# Value                              float64
# Wage                               float64
# Preferred Foot                      object
# International Reputation           float64
# Weak Foot                          float64
# Skill Moves                        float64
# Work Rate                           object
# Body Type                           object
# Position                            object
# Jersey Number                      float64
# Joined                               int32
# Contract Valid Until        datetime64[ns]
# Height                              object
# Weight                              object
# Crossing                           float64
# ...

# %%
#Checking height weight data type
Fifa_Df['Height'].dtype
Fifa_Df['Weight'].dtype
# Out:
# dtype('O')

# %% [markdown]
# <strong>7. The column 'Height' is in inches with a quotation mark, Convert to float
# with decimal points.</strong>

# %%
#The column 'Height' is in inches with a quotation mark, Convert to float with decimal points.
Fifa_Df['Height']=Fifa_Df['Height'].str.replace("'",'.').astype(float)
Fifa_Df['Height'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# <strong>8. The column "Weight" has the suffix as lbs, remove the suffix and convert
# to float.</strong>

# %%
#The column "Weight" has the suffix as lbs, remove the suffix and convertto float.
Fifa_Df['Weight']=Fifa_Df['Weight'].str.strip('lbs').astype(float)
Fifa_Df.head(3)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
#
#                   Club        Value      Wage Preferred Foot  \
# 0         FC Barcelona  110500000.0  565000.0           Left
# 1             Juventus   77000000.0  405000.0          Right
# 2  Paris Saint-Germain  118500000.0  290000.0          Right
#
#    International Reputation  Weak Foot  Skill Moves       Work Rate  \
# 0                       5.0        4.0          4.0  Medium/ Medium
# 1                       5.0        4.0          5.0       High/ Low
# 2                       5.0        5.0          5.0    High/ Medium
#
#     Body Type Position  Jersey Number  Joined Contract Valid Until  Height  \
# 0       Messi       RF           10.0    2004           2021-12-31     5.7
# ...

# %% [markdown]
# <strong>9. Check for the percentage of missing values and impute them with
# appropriate imputation techniques.</strong>

# %%
#Check for the percentage of missing values and impute them with appropriate imputation techniques.
missing_margin=Fifa_Df.isnull().sum()*100/len(Fifa_Df)
print(missing_margin)
# Out:
# ID                          0.000000
# Name                        0.000000
# Age                         0.000000
# Nationality                 0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        1.323667
# Value                       0.000000
# Wage                        0.000000
# Preferred Foot              0.263635
# International Reputation    0.263635
# Weak Foot                   0.263635
# Skill Moves                 0.263635
# Work Rate                   0.263635
# Body Type                   0.263635
# Position                    0.329544
# Jersey Number               0.329544
# Joined                      0.000000
# Contract Valid Until        8.529686
# Height                      0.263635
# Weight                      0.263635
# Crossing                    0.263635
# Finishing                   0.263635
# HeadingAccuracy             0.263635
# ShortPassing                0.263635
# ...

# %%
#Remove all rows with NULL values from the DataFrame
print(Fifa_Df.dropna())
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club        Value      Wage Preferred Foot  \
# ...

# %% [markdown]
# <strong>10. Plot the distribution of Overall rating for all the players and write your findings</strong>

# %%
Fig, ax = plt.subplots(1, 2, figsize=(8,4))
sns.distplot(Fifa_Df['Overall'],bins=15,ax=ax[0])
sns.boxplot(Fifa_Df['Overall'],ax=ax[1],color='pink')
plt.show()

# %% [markdown]
# Ploting the distribution of Overall rating for all the players. Ratings are skewed positively.

# %% [markdown]
# <strong>11. Retrieve the names of top20 players based on the Overall rating.</strong>

# %%
Fifa_Overall_top20=Fifa_Df.copy()
Fifa_Overall_top20=Fifa_Overall_top20.sort_values(by='Overall',ascending=False)
print(Fifa_Overall_top20[['Name','Overall']].head(20))
# Out:
#                  Name  Overall
# 0            L. Messi       94
# 1   Cristiano Ronaldo       94
# 2           Neymar Jr       92
# 3              De Gea       91
# 4        K. De Bruyne       91
# 5           E. Hazard       91
# 6           L. Modrić       91
# 7           L. Suárez       91
# 8        Sergio Ramos       91
# 12           D. Godín       90
# 13        David Silva       90
# 9            J. Oblak       90
# 11           T. Kroos       90
# 10     R. Lewandowski       90
# 20    Sergio Busquets       89
# 24       G. Chiellini       89
# 23          S. Agüero       89
# 22           M. Neuer       89
# 21          E. Cavani       89
# 16            H. Kane       89

# %% [markdown]
# <strong>12. Generate a dataframe which should include all the information of the Top 20 players based on the Overall rating</strong>

# %%
top20_info=pd.DataFrame(Fifa_Overall_top20.head(20))
top20_info
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 2   190871          Neymar Jr   26      Brazil       92         93
# 3   193080             De Gea   27       Spain       91         93
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 7   176580          L. Suárez   31     Uruguay       91         91
# 8   155862       Sergio Ramos   32       Spain       91         91
# 12  182493           D. Godín   32     Uruguay       90         90
# 13  168542        David Silva   32       Spain       90         90
# 9   200389           J. Oblak   25    Slovenia       90         93
# 11  182521           T. Kroos   28     Germany       90         90
# ...

# %% [markdown]
# <strong>13. What is the average "Age" and "Wage" of these top 20 players? (use the data frame created in the question 11)</strong>

# %%
# top20_info[['Age','Wage']].head(20)
Avg_age = round(top20_info['Age'].mean())
Avg_wage = round(top20_info['Wage'].mean())

print("Average Age : ",Avg_age,"yrs") 
print("Average Wage : €",Avg_wage)
# Out:
# Average Age :  30 yrs
# Average Wage : € 294950

# %% [markdown]
# <strong>14. Among the top 20 players based on the Overall rating, which player has the highest wage?
# Display the name of the player with his wage.</strong>

# %%
top20_info.sort_values(by=['Wage','Overall'],axis=0,ascending=[False,False],inplace=False,kind='quicksort', na_position='first', ignore_index=True, key=None)
print(top20_info[['Name','Wage']].head(1))
# Out:
#        Name      Wage
# 0  L. Messi  565000.0

# %% [markdown]
# <strong>15.Generate a dataframe which should include the "Player name", "ClubName", "Wage", and 'Overall rating'.
# - i) find the average Overall rating for each club.
# - ii) Display the average overall rating of Top10 Clubs using a plot</strong>

# %%
Fifa_Df_colm=Fifa_Df[['Name','Club','Overall','Wage']]
Fifa_Df_colm.head()
# Out:
#                 Name                 Club  Overall      Wage
# 0           L. Messi         FC Barcelona       94  565000.0
# 1  Cristiano Ronaldo             Juventus       94  405000.0
# 2          Neymar Jr  Paris Saint-Germain       92  290000.0
# 3             De Gea    Manchester United       91  260000.0
# 4       K. De Bruyne      Manchester City       91  355000.0

# %%
# - i) find the average Overall rating for each club.
Fifa_Df_colm.groupby('Club')['Overall'].mean()
# Out:
# Club
#  SSV Jahn Regensburg     65.586207
# 1. FC Heidenheim 1846    65.750000
# 1. FC Kaiserslautern     63.384615
# 1. FC Köln               70.785714
# 1. FC Magdeburg          65.615385
#                            ...
# Zagłębie Sosnowiec       60.760000
# Çaykur Rizespor          66.900000
# Örebro SK                60.481481
# Östersunds FK            63.545455
# Śląsk Wrocław            62.200000
# Name: Overall, Length: 651, dtype: float64

# %%
#Display average overall rating
Fifa_DF_colm['Club Overall']=Fifa_DF_colm['Overall'].rank(method='average',ascending=False)
Fifa_DF_top10_club=Fifa_DF_colm.sort_values(['Club Overall'],ascending=True).head(10)
plt.figure(figsize=(10,5))
sns.barplot(y='Club', x='Club Overall', data= Fifa_DF_top10_club)

print(Fifa_DF_top10_club)
plt.show()
# Out:
#                  Name                 Club  Overall      Wage  Club Overall
# 0            L. Messi         FC Barcelona       94  565000.0           1.5
# 1   Cristiano Ronaldo             Juventus       94  405000.0           1.5
# 2           Neymar Jr  Paris Saint-Germain       92  290000.0           3.0
# 3              De Gea    Manchester United       91  260000.0           6.5
# 4        K. De Bruyne      Manchester City       91  355000.0           6.5
# 5           E. Hazard              Chelsea       91  340000.0           6.5
# 6           L. Modrić          Real Madrid       91  420000.0           6.5
# 7           L. Suárez         FC Barcelona       91  455000.0           6.5
# 8        Sergio Ramos          Real Madrid       91  380000.0           6.5
# 13        David Silva      Manchester City       90  285000.0          12.0

# %% [markdown]
# The average overall rating of Top10 Clubs using a plot

# %% [markdown]
# <strong>16. What is the relationship between age and individual potential of the
# player? Visualize the relationship with appropriate plot and Comment on
# the same</strong>

# %%
Fifa_Df_Age_Pot_cor = Fifa_Df['Age'].corr(Fifa_Df['Potential'])
print("Correlation between Age and Potential is ", round(Fifa_Df_Age_Pot_cor,2))
# Out:
# Correlation between Age and Potential is  -0.25

# %%
# Visualize the relationship with appropriate plot and Comment on the same
plt.figure(figsize=(20,5))
sns.lineplot(x= 'Age', y= 'Potential', data = Fifa_Df, color='green')
plt.show()

# %% [markdown]
# It is observed that as the age of the player increases the potential depleads and finally
# beyond the age group of 44 there is a exponential growth in potential of the player.

# %% [markdown]
# <strong>17. Which features directly contribute to the wages of the players?
# Support your answer with a plot and a metric.</strong>

# %%
Fifa_Df_wageRel=Fifa_Df[['Potential','Overall','Value','International Reputation','Release Clause','Wage']]
Fifa_Df_wageRel.corr()
# Out:
#                           Potential   Overall     Value  \
# Potential                  1.000000  0.660939  0.576218
# Overall                    0.660939  1.000000  0.627085
# Value                      0.576218  0.627085  1.000000
# International Reputation   0.372993  0.499491  0.653176
# Release Clause             0.547668  0.589200  0.967255
# Wage                       0.486413  0.571926  0.858442
#
#                           International Reputation  Release Clause      Wage
# Potential                                 0.372993        0.547668  0.486413
# Overall                                   0.499491        0.589200  0.571926
# Value                                     0.653176        0.967255  0.858442
# International Reputation                  1.000000        0.618094  0.668635
# Release Clause                            0.618094        1.000000  0.820162
# Wage                                      0.668635        0.820162  1.000000

# %%
sns.heatmap(Fifa_Df_wageRel[['Potential','Overall','Value','Release Clause','International Reputation']].corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot: >

# %% [markdown]
#  Features directly contribute to the wages of the players
#   Value and Relase Clause are directily prepostional to one another.

# %%
# Support your answer with a plot and a metric.
sns.pairplot(Fifa_Df_wageRel[['Wage', 'Potential', 'Overall', 'Value', 'International Reputation', 'Release Clause']])
plt.show()

# %% [markdown]
# Support your answer with a plot and a metric

# %% [markdown]
# <strong>18. Find the position in the pitch where the maximum number of players play
# and the position where the minimum number of players play? Display it using a plot.</strong>

# %%
Df_pos=Fifa_Df.groupby(['Position'])['Position'].count().reset_index(name='Count').sort_values(by=('Count'),ascending=False)
print("Maximum players paying at Position :"+Df_pos['Position'][Df_pos['Count']==Df_pos['Count'].max()].iloc[0])
print("Minimum players paying at Position :"+ Df_pos['Position'][Df_pos['Count']==Df_pos['Count'].min()].iloc[0])
# Out:
# Maximum players paying at Position :ST
# Minimum players paying at Position :LF

# %%
# Display it using a plot.
plt.figure(figsize=(20,10))
sns.lineplot(x= 'Position', y= 'Count', data = Df_pos, color='red')
plt.show()

# %% [markdown]
# Ploting position and number of player

# %% [markdown]
# <strong>19.How many players are from the club 'Juventus' and the wage is greater than 200K?
# Display all the information of such players</strong>

# %%
Fifa_Juve=np.where((Fifa_Df['Club']=='Juventus') & (Fifa_Df['Wage']>200000))
Fifa_juve_filter=Fifa_Df.loc[Fifa_Juve]
print(str(Fifa_juve_filter['Club'].count())+" Players in Juventus Club with wages greater than 200k")
# Out:
# 3 Players in Juventus Club with wages greater than 200k

# %%
Fifa_juve_filter.head()
# Out:
#         ID               Name  Age Nationality  Overall  Potential      Club  \
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94  Juventus
# 15  211110          P. Dybala   24   Argentina       89         94  Juventus
# 24  138956       G. Chiellini   33       Italy       89         89  Juventus
#
#          Value      Wage Preferred Foot  International Reputation  Weak Foot  \
# 1   77000000.0  405000.0          Right                       5.0        4.0
# 15  89000000.0  205000.0           Left                       3.0        3.0
# 24  27000000.0  215000.0           Left                       4.0        3.0
#
#     Skill Moves     Work Rate   Body Type Position  Jersey Number  Joined  \
# 1           5.0     High/ Low  C. Ronaldo       ST            7.0    2018
# 15          4.0  High/ Medium      Normal       LF           21.0    2015
# 24          2.0  Medium/ High      Normal      LCB            3.0    2005
#
# ...

# %% [markdown]
# <strong>20. Generate a data frame containing top 5 players by Overall rating for
# each unique position.</strong>

# %%
df_top5_unique_pos = Fifa_Df.groupby(by = ['Position']).apply(lambda x: x.sort_values('Overall', ascending = False).head(5))
display(df_top5_unique_pos)
# Out:
#                  ID               Name  Age Nationality  Overall  Potential  \
# Position
# CAM      17  194765       A. Griezmann   27      France       89         90
#          31  190460         C. Eriksen   26     Denmark       88         91
#          61  201942    Roberto Firmino   26      Brazil       86         87
#          66  189596          T. Müller   28     Germany       86         86
#          74  176635            M. Özil   29     Germany       86         86
# ...             ...                ...  ...         ...      ...        ...
# ST       1    20801  Cristiano Ronaldo   33    Portugal       94         94
#          10  188545     R. Lewandowski   29      Poland       90         90
#          16  202126            H. Kane   24     England       89         91
#          23  153079          S. Agüero   30   Argentina       89         89
#          36  173731            G. Bale   28       Wales       88         88
#
# ...

# %% [markdown]
# <strong>21. What is the average wage one can expect to pay for the top 5 players
# in every position? (use the data frame created in Q19)</strong>

# %%
avg_wage= df_top5_unique_pos['Wage'].groupby('Position').apply(np.mean)
print(avg_wage)
# Out:
# Position
# CAM    174000.0
# CB     139600.0
# CDM    217000.0
# CF      47400.0
# CM     130600.0
# GK     192800.0
# LAM     81600.0
# LB     177200.0
# LCB    162000.0
# LCM    184400.0
# LDM    126600.0
# LF     121200.0
# LM     164600.0
# LS     130200.0
# LW     261000.0
# LWB     34200.0
# RAM     45400.0
# RB     155400.0
# RCB    231000.0
# RCM    240800.0
# RDM    105000.0
# RF     148000.0
# RM     131400.0
# RS     132200.0
# RW     202000.0
# RWB     44200.0
# ST     294000.0
# Name: Wage, dtype: float64
